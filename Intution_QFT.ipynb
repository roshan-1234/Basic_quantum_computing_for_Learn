# %%
from qiskit.circuit.library import QFT
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector
from qiskit import QuantumCircuit

# %%
state='000' ##Changes this set to 100, 010,001

mycircuit = QuantumCircuit(len(state))
mycircuit.initialize(Statevector.from_label(state).data,mycircuit.qubits[::-1])
print(f"Comptitional basis |{state}>")
display(plot_bloch_multivector(Statevector.from_instruction(mycircuit).data))
print(f"Fourier basis |{state}>")
mycircuit.append(QFT(len(state),do_swaps
                     =True),mycircuit.qubits)
display(plot_bloch_multivector(Statevector.from_instruction(mycircuit).data))
# Out:
# Comptitional basis |000>
# Fourier basis |000>

# %% [markdown]
# For more details visit Qiskit textbook \url{https://learn.qiskit.org/course/ch-algorithms/quantum-fourier-transform#intuition}
